# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r'C:\Users\RISHU YADAV\Downloads\train.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.groupby('Sex').get_group('male')
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.groupby('Sex').get_group('female')
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[['Sex','Age']]
# Out:
#         Sex   Age
# 0      male  22.0
# 1    female  38.0
# 2    female  26.0
# 3    female  35.0
# 4      male  35.0
# ..      ...   ...
# 886    male  27.0
# 887  female  19.0
# 888  female   NaN
# 889    male  26.0
# 890    male  32.0
#
# [891 rows x 2 columns]

# %%
df.fillna(method='ffill','Age')
# Out:
#   File "<ipython-input-12-e2f3de8d90bd>", line 1
#     df.fillna(method='ffill','Age')
#                              ^
# SyntaxError: positional argument follows keyword argument

# %%
df.fillna(method='pad')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
x=df.loc[df['Sex']=='male',['Age','Sex','Cabin']]

# %%
x
# Out:
#       Age   Sex Cabin
# 0    22.0  male   NaN
# 4    35.0  male   NaN
# 5     NaN  male   NaN
# 6    54.0  male   E46
# 7     2.0  male   NaN
# ..    ...   ...   ...
# 883  28.0  male   NaN
# 884  25.0  male   NaN
# 886  27.0  male   NaN
# 889  26.0  male  C148
# 890  32.0  male   NaN
#
# [577 rows x 3 columns]

# %%
x=df.loc[df['Sex']=='male',['Name','Sex','Survived']]

# %%
x
# Out:
#                                Name   Sex  Survived
# 0           Braund, Mr. Owen Harris  male         0
# 4          Allen, Mr. William Henry  male         0
# 5                  Moran, Mr. James  male         0
# 6           McCarthy, Mr. Timothy J  male         0
# 7    Palsson, Master. Gosta Leonard  male         0
# ..                              ...   ...       ...
# 883   Banfield, Mr. Frederick James  male         0
# 884          Sutehall, Mr. Henry Jr  male         0
# 886           Montvila, Rev. Juozas  male         0
# 889           Behr, Mr. Karl Howell  male         1
# 890             Dooley, Mr. Patrick  male         0
#
# [577 rows x 3 columns]

# %%
x=df.loc[df['Sex']=='female',['Name','Sex','Survived']]

# %%
x
# Out:
#                                                   Name     Sex  Survived
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female         1
# 2                               Heikkinen, Miss. Laina  female         1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female         1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female         1
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female         1
# ..                                                 ...     ...       ...
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  female         1
# 882                       Dahlberg, Miss. Gerda Ulrika  female         0
# 885               Rice, Mrs. William (Margaret Norton)  female         0
# 887                       Graham, Miss. Margaret Edith  female         1
# 888           Johnston, Miss. Catherine Helen "Carrie"  female         0
#
# [314 rows x 3 columns]

# %%
x=df.loc[df['Sex']=='male',['Name','Age','Sex','Ticket','Cabin']]

# %%
x
# Out:
#                                Name   Age   Sex            Ticket Cabin
# 0           Braund, Mr. Owen Harris  22.0  male         A/5 21171   NaN
# 4          Allen, Mr. William Henry  35.0  male            373450   NaN
# 5                  Moran, Mr. James   NaN  male            330877   NaN
# 6           McCarthy, Mr. Timothy J  54.0  male             17463   E46
# 7    Palsson, Master. Gosta Leonard   2.0  male            349909   NaN
# ..                              ...   ...   ...               ...   ...
# 883   Banfield, Mr. Frederick James  28.0  male  C.A./SOTON 34068   NaN
# 884          Sutehall, Mr. Henry Jr  25.0  male   SOTON/OQ 392076   NaN
# 886           Montvila, Rev. Juozas  27.0  male            211536   NaN
# 889           Behr, Mr. Karl Howell  26.0  male            111369  C148
# 890             Dooley, Mr. Patrick  32.0  male            370376   NaN
#
# [577 rows x 5 columns]

# %%
sns.barplot('Sex','Pclass',data=df)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Sex', ylabel='Pclass'>

# %%
sns.lineplot('Sex','Pclass',data=df)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Sex', ylabel='Pclass'>

# %%
sns.barplot('Sex','Age',data=df)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Sex', ylabel='Age'>

# %%
df['family']=df['SibSp']+df['Parch']

# %%
df['family']
# Out:
# 0      1
# 1      1
# 2      0
# 3      1
# 4      0
#       ..
# 886    0
# 887    0
# 888    3
# 889    0
# 890    0
# Name: family, Length: 891, dtype: int64

# %%
df1=df['SibSp']

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
drop_of_sibsp=df.drop('SibSp',axis=1)

# %%
drop_of_sibsp
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  Parch  \
# 0                              Braund, Mr. Owen Harris    male  22.0      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      0
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      0
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
drop_of_paarch=df.drop('Parch',axis=1)

# %%
drop_of_paarch
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1
# Out:
# 0      1
# 1      1
# 2      0
# 3      1
# 4      0
#       ..
# 886    0
# 887    0
# 888    1
# 889    0
# 890    0
# Name: SibSp, Length: 891, dtype: int64

# %%
#From where max & min passenger board to titanic also define their

# %%
df["Age"].max()
# Out:
# 80.0

# %%
df["Age"].mean()
# Out:
# 29.69911764705882

# %%
df["Name"].min()
# Out:
# 'Abbing, Mr. Anthony'

# %%
df['Age'].aggregate(['max', 'min',np.mean])
# Out:
# max     80.000000
# min      0.420000
# mean    29.699118
# Name: Age, dtype: float64

# %%
df[['Age','Name']].max()
# Out:
# Age                            80.0
# Name    van Melkebeke, Mr. Philemon
# dtype: object

# %%
df[['Age','Name']].min()
# Out:
# Age                    0.42
# Name    Abbing, Mr. Anthony
# dtype: object

# %%
df['Fare'].max()
# Out:
# 512.3292

# %%
df['Fare'].min()
# Out:
# 0.0

# %%
#what is gender ratio of survived passenger.

# %%
survived_pass=df.loc[df['Survived']==1,['Sex','Survived']]

# %%
survived_pass
# Out:
#         Sex  Survived
# 1    female         1
# 2    female         1
# 3    female         1
# 8    female         1
# 9    female         1
# ..      ...       ...
# 875  female         1
# 879  female         1
# 880  female         1
# 887  female         1
# 889    male         1
#
# [342 rows x 2 columns]

# %%
unsurvived_pass=df.loc[df['Survived']==0,['Sex','Survived']]

# %%
unsurvived_pass
# Out:
#         Sex  Survived
# 0      male         0
# 4      male         0
# 5      male         0
# 6      male         0
# 7      male         0
# ..      ...       ...
# 884    male         0
# 885  female         0
# 886    male         0
# 888  female         0
# 890    male         0
#
# [549 rows x 2 columns]

# %%
sns.countplot('Survived',data=df)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
#From where max & min passenger board to titanic also define their

# %%
df['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
df['Embarked'].mode().value_counts()
# Out:
# S    1
# dtype: int64

# %%
df[['Embarked','Fare']].aggregate(['max', 'min'])
# Out:
#          Fare
# max  512.3292
# min    0.0000

# %%
max_min_pass_count=df['Embarked'].value_counts()

# %%
max_min_pass_count
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
max_min_pass_count.plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='Embarked'>

# %%
max_min_pass_count.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.countplot['Embarked',data=max_min_pass_count]
# Out:
#   File "<ipython-input-81-41d506e05642>", line 1
#     sns.countplot['Embarked',data=max_min_pass_count]
#                                  ^
# SyntaxError: invalid syntax

# %%
df[['Age','Embarked']].value_counts()
# Out:
# Age   Embarked
# 24.0  S           23
# 28.0  S           23
# 19.0  S           22
# 21.0  S           21
# 18.0  S           21
#                   ..
# 28.5  S            1
#       C            1
# 25.0  Q            1
# 24.5  S            1
# 80.0  S            1
# Length: 162, dtype: int64

# %%
avg_age_S=df.loc[df['Embarked']=='S',['Name','Age','Embarked']]

# %%
avg_age_S
# Out:
#                                              Name   Age Embarked
# 0                         Braund, Mr. Owen Harris  22.0        S
# 2                          Heikkinen, Miss. Laina  26.0        S
# 3    Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0        S
# 4                        Allen, Mr. William Henry  35.0        S
# 6                         McCarthy, Mr. Timothy J  54.0        S
# ..                                            ...   ...      ...
# 883                 Banfield, Mr. Frederick James  28.0        S
# 884                        Sutehall, Mr. Henry Jr  25.0        S
# 886                         Montvila, Rev. Juozas  27.0        S
# 887                  Graham, Miss. Margaret Edith  19.0        S
# 888      Johnston, Miss. Catherine Helen "Carrie"   NaN        S
#
# [644 rows x 3 columns]

# %%
avg_age_S.mean()
# Out:
# Age    29.445397
# dtype: float64

# %%
avg_age_Q=df.loc[df['Embarked']=='Q',['Name','Age','Embarked']]

# %%
avg_age_Q
# Out:
#                                      Name   Age Embarked
# 5                        Moran, Mr. James   NaN        Q
# 16                   Rice, Master. Eugene   2.0        Q
# 22            McGowan, Miss. Anna "Annie"  15.0        Q
# 28          O'Dwyer, Miss. Ellen "Nellie"   NaN        Q
# 32               Glynn, Miss. Mary Agatha   NaN        Q
# ..                                    ...   ...      ...
# 790              Keane, Mr. Andrew "Andy"   NaN        Q
# 825                       Flynn, Mr. John   NaN        Q
# 828          McCormack, Mr. Thomas Joseph   NaN        Q
# 885  Rice, Mrs. William (Margaret Norton)  39.0        Q
# 890                   Dooley, Mr. Patrick  32.0        Q
#
# [77 rows x 3 columns]

# %%
avg_age_Q.mean()
# Out:
# Age    28.089286
# dtype: float64

# %%
avg_age_Q=df.loc[df['Embarked']=='Q',['Name','Age','Embarked']]
