# %%
import pandas as pd

# %%
data=pd.read_csv(r"C:\Users\RISHU YADAV\Downloads/framingham.csv")

# %%
data
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
# 4238     1   40        3.0              0         0.0     0.0
# 4239     0   39        3.0              1        30.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# ...

# %%
data.tail()
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
# 4238     1   40        3.0              0         0.0     0.0
# 4239     0   39        3.0              1        30.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 4235                0             0         0    248.0  131.0   72.0  22.00
# 4236                0             0         0    210.0  126.5   87.0  19.16
# 4237                0             0         0    269.0  133.5   83.0  21.47
# 4238                0             1         0    185.0  141.0   98.0  25.60
# 4239                0             0         0    196.0  133.0   86.0  20.91
#
#       heartRate  glucose  TenYearCHD
# 4235       84.0     86.0           0
# 4236       86.0      NaN           0
# ...

# %%
data.head()
# Out:
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39        4.0              0         0.0     0.0                0
# 1     0   46        2.0              0         0.0     0.0                0
# 2     1   48        1.0              1        20.0     0.0                0
# 3     0   61        3.0              1        30.0     0.0                0
# 4     0   46        3.0              1        23.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1             0         0    250.0  121.0   81.0  28.73       95.0     76.0
# 2             0         0    245.0  127.5   80.0  25.34       75.0     70.0
# 3             1         0    225.0  150.0   95.0  28.58       65.0    103.0
# 4             0         0    285.0  130.0   84.0  23.10       85.0     85.0
#
#    TenYearCHD
# 0           0
# 1           0
# ...

# %%
data.iloc[0:4,0:3]
# Out:
#    male  age  education
# 0     1   39        4.0
# 1     0   46        2.0
# 2     1   48        1.0
# 3     0   61        3.0

# %%
data.iloc[10:13,3:4]
# Out:
#     currentSmoker
# 10              0
# 11              0
# 12              1

# %%
data["currentSmoker"].value_counts()
# Out:
# 0    2145
# 1    2095
# Name: currentSmoker, dtype: int64

# %%
data1=data.query('age>50')

# %%
data.head()
# Out:
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39        4.0              0         0.0     0.0                0
# 1     0   46        2.0              0         0.0     0.0                0
# 2     1   48        1.0              1        20.0     0.0                0
# 3     0   61        3.0              1        30.0     0.0                0
# 4     0   46        3.0              1        23.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1             0         0    250.0  121.0   81.0  28.73       95.0     76.0
# 2             0         0    245.0  127.5   80.0  25.34       75.0     70.0
# 3             1         0    225.0  150.0   95.0  28.58       65.0    103.0
# 4             0         0    285.0  130.0   84.0  23.10       85.0     85.0
#
#    TenYearCHD
# 0           0
# 1           0
# ...

# %%
data.groupby(["male","education"])[["cigsPerDay","heartRate","glucose"]].mean()
# Out:
#                 cigsPerDay  heartRate    glucose
# male education
# 0    1.0          4.679829  77.147402  82.990544
#      2.0          7.025033  78.257853  81.400894
#      3.0          5.768398  76.422414  80.926471
#      4.0          5.591837  74.467005  79.720000
# 1    1.0         13.536869  74.795103  83.184573
#      2.0         14.243299  74.312883  80.461707
#      3.0         12.986486  74.533333  83.772093
#      4.0         12.313869  72.630435  80.560311

# %%
data.groupby(["male","education"])[["cigsPerDay","heartRate"]].mean()
# Out:
#                 cigsPerDay  heartRate
# male education
# 0    1.0          4.679829  77.147402
#      2.0          7.025033  78.257853
#      3.0          5.768398  76.422414
#      4.0          5.591837  74.467005
# 1    1.0         13.536869  74.795103
#      2.0         14.243299  74.312883
#      3.0         12.986486  74.533333
#      4.0         12.313869  72.630435

# %%
data.groupby(["male","education","currentSmoker"])[["cigsPerDay","heartRate","glucose"]].mean()
# Out:
#                               cigsPerDay  heartRate    glucose
# male education currentSmoker
# 0    1.0       0                0.000000  76.731942  84.479860
#                1               13.964968  77.956250  79.898182
#      2.0       0                0.000000  77.872818  82.803324
#                1               14.893855  78.683196  79.767742
#      3.0       0                0.000000  75.776119  79.851064
#                1               13.737113  77.306122  82.387283
#      4.0       0                0.000000  74.222222  78.810526
#                1               12.454545  74.764045  80.800000
# 1    1.0       0                0.000000  72.311644  86.425455
#                1               21.754678  76.293388  81.208426
#      2.0       0                0.000000  73.317919  80.907407
#                1               22.141026  74.857595  80.216949
#      3.0       0                0.000000  72.545455  88.542553
# ...

# %%
keysnack
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-4c5dbc1a6285> in <module>
# ----> 1 keysnack
#
# NameError: name 'keysnack' is not defined

# %%
pd.pivot_table(data,values=["age","education"],index=["male"],aggfunc=[min,max])
# Out:
#      min           max
#      age education age education
# male
# 0     32       1.0  70       4.0
# 1     33       1.0  69       4.0

# %%
import pandas as pd

# %%
data=pd.read_csv(r"C:\Users\RISHU YADAV\Downloads/framingham.csv")

# %%
data.head(5)
# Out:
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39        4.0              0         0.0     0.0                0
# 1     0   46        2.0              0         0.0     0.0                0
# 2     1   48        1.0              1        20.0     0.0                0
# 3     0   61        3.0              1        30.0     0.0                0
# 4     0   46        3.0              1        23.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1             0         0    250.0  121.0   81.0  28.73       95.0     76.0
# 2             0         0    245.0  127.5   80.0  25.34       75.0     70.0
# 3             1         0    225.0  150.0   95.0  28.58       65.0    103.0
# 4             0         0    285.0  130.0   84.0  23.10       85.0     85.0
#
#    TenYearCHD
# 0           0
# 1           0
# ...

# %%
data.tail(7)
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 4233     1   50        1.0              1         1.0     0.0
# 4234     1   51        3.0              1        43.0     0.0
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
# 4238     1   40        3.0              0         0.0     0.0
# 4239     0   39        3.0              1        30.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 4233                0             1         0    313.0  179.0   92.0  25.97
# 4234                0             0         0    207.0  126.5   80.0  19.71
# 4235                0             0         0    248.0  131.0   72.0  22.00
# 4236                0             0         0    210.0  126.5   87.0  19.16
# 4237                0             0         0    269.0  133.5   83.0  21.47
# ...

# %%
data.shape
# Out:
# (4240, 16)

# %%
data["male"]
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 4235    0
# 4236    0
# 4237    0
# 4238    1
# 4239    0
# Name: male, Length: 4240, dtype: int64

# %%
data["education"]
# Out:
# 0       4.0
# 1       2.0
# 2       1.0
# 3       3.0
# 4       3.0
#        ...
# 4235    2.0
# 4236    1.0
# 4237    2.0
# 4238    3.0
# 4239    3.0
# Name: education, Length: 4240, dtype: float64

# %%
data.head(2)
# Out:
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39        4.0              0         0.0     0.0                0
# 1     0   46        2.0              0         0.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1             0         0    250.0  121.0   81.0  28.73       95.0     76.0
#
#    TenYearCHD
# 0           0
# 1           0

# %%
data.iloc[:,1:4]
# Out:
#       age  education  currentSmoker
# 0      39        4.0              0
# 1      46        2.0              0
# 2      48        1.0              1
# 3      61        3.0              1
# 4      46        3.0              1
# ...   ...        ...            ...
# 4235   48        2.0              1
# 4236   44        1.0              1
# 4237   52        2.0              0
# 4238   40        3.0              0
# 4239   39        3.0              1
#
# [4240 rows x 3 columns]

# %%
data.iloc[1:4,1:4]
# Out:
#    age  education  currentSmoker
# 1   46        2.0              0
# 2   48        1.0              1
# 3   61        3.0              1

# %%
data.drop(["education"],axis=1)
# Out:
#       male  age  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0        1   39              0         0.0     0.0                0
# 1        0   46              0         0.0     0.0                0
# 2        1   48              1        20.0     0.0                0
# 3        0   61              1        30.0     0.0                0
# 4        0   46              1        23.0     0.0                0
# ...    ...  ...            ...         ...     ...              ...
# 4235     0   48              1        20.0     NaN                0
# 4236     0   44              1        15.0     0.0                0
# 4237     0   52              0         0.0     0.0                0
# 4238     1   40              0         0.0     0.0                0
# 4239     0   39              1        30.0     0.0                0
#
#       prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  \
# 0                0         0    195.0  106.0   70.0  26.97       80.0
# ...

# %%
data.head()
# Out:
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39        4.0              0         0.0     0.0                0
# 1     0   46        2.0              0         0.0     0.0                0
# 2     1   48        1.0              1        20.0     0.0                0
# 3     0   61        3.0              1        30.0     0.0                0
# 4     0   46        3.0              1        23.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1             0         0    250.0  121.0   81.0  28.73       95.0     76.0
# 2             0         0    245.0  127.5   80.0  25.34       75.0     70.0
# 3             1         0    225.0  150.0   95.0  28.58       65.0    103.0
# 4             0         0    285.0  130.0   84.0  23.10       85.0     85.0
#
#    TenYearCHD
# 0           0
# 1           0
# ...

# %%
data.columns
# Out:
# Index(['male', 'age', 'education', 'currentSmoker', 'cigsPerDay', 'BPMeds',
#        'prevalentStroke', 'prevalentHyp', 'diabetes', 'totChol', 'sysBP',
#        'diaBP', 'BMI', 'heartRate', 'glucose', 'TenYearCHD'],
#       dtype='object')

# %%
data.isnull()
# Out:
#        male    age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0     False  False      False          False       False   False
# 1     False  False      False          False       False   False
# 2     False  False      False          False       False   False
# 3     False  False      False          False       False   False
# 4     False  False      False          False       False   False
# ...     ...    ...        ...            ...         ...     ...
# 4235  False  False      False          False       False    True
# 4236  False  False      False          False       False   False
# 4237  False  False      False          False       False   False
# 4238  False  False      False          False       False   False
# 4239  False  False      False          False       False   False
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0               False         False     False    False  False  False  False
# ...

# %%
data.isnull().sum()
# Out:
# male                 0
# age                  0
# education          105
# currentSmoker        0
# cigsPerDay          29
# BPMeds              53
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol             50
# sysBP                0
# diaBP                0
# BMI                 19
# heartRate            1
# glucose            388
# TenYearCHD           0
# dtype: int64

# %%
data.isnull().any()
# Out:
# male               False
# age                False
# education           True
# currentSmoker      False
# cigsPerDay          True
# BPMeds              True
# prevalentStroke    False
# prevalentHyp       False
# diabetes           False
# totChol             True
# sysBP              False
# diaBP              False
# BMI                 True
# heartRate           True
# glucose             True
# TenYearCHD         False
# dtype: bool

# %%
x=data.dropna()

# %%
x.shape
# Out:
# (3658, 16)

# %%
x.isnull().any()
# Out:
# male               False
# age                False
# education          False
# currentSmoker      False
# cigsPerDay         False
# BPMeds             False
# prevalentStroke    False
# prevalentHyp       False
# diabetes           False
# totChol            False
# sysBP              False
# diaBP              False
# BMI                False
# heartRate          False
# glucose            False
# TenYearCHD         False
# dtype: bool

# %%
x.isnull().sum()
# Out:
# male               0
# age                0
# education          0
# currentSmoker      0
# cigsPerDay         0
# BPMeds             0
# prevalentStroke    0
# prevalentHyp       0
# diabetes           0
# totChol            0
# sysBP              0
# diaBP              0
# BMI                0
# heartRate          0
# glucose            0
# TenYearCHD         0
# dtype: int64

# %%
x.isnull().any().sum()
# Out:
# 0

# %%
data.isnull().any().sum()
# Out:
# 7

# %%
data.isnull().sum()
# Out:
# male                 0
# age                  0
# education          105
# currentSmoker        0
# cigsPerDay          29
# BPMeds              53
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol             50
# sysBP                0
# diaBP                0
# BMI                 19
# heartRate            1
# glucose            388
# TenYearCHD           0
# dtype: int64

# %%
x.head(2)
# Out:
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39        4.0              0         0.0     0.0                0
# 1     0   46        2.0              0         0.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1             0         0    250.0  121.0   81.0  28.73       95.0     76.0
#
#    TenYearCHD
# 0           0
# 1           0

# %%
type(x)
# Out:
# pandas.core.frame.DataFrame

# %%
x.iloc[:,1:2]
# Out:
#       age
# 0      39
# 1      46
# 2      48
# 3      61
# 4      46
# ...   ...
# 4233   50
# 4234   51
# 4237   52
# 4238   40
# 4239   39
#
# [3658 rows x 1 columns]

# %%
data2=data.fillna(data.mean())

# %%
data.isnull().sum()
# Out:
# male                 0
# age                  0
# education          105
# currentSmoker        0
# cigsPerDay          29
# BPMeds              53
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol             50
# sysBP                0
# diaBP                0
# BMI                 19
# heartRate            1
# glucose            388
# TenYearCHD           0
# dtype: int64

# %%
data2.isnull().sum()
# Out:
# male               0
# age                0
# education          0
# currentSmoker      0
# cigsPerDay         0
# BPMeds             0
# prevalentStroke    0
# prevalentHyp       0
# diabetes           0
# totChol            0
# sysBP              0
# diaBP              0
# BMI                0
# heartRate          0
# glucose            0
# TenYearCHD         0
# dtype: int64

# %%
data3=data.fillna(data.median())

# %%
data3.isnull().sum()
# Out:
# male               0
# age                0
# education          0
# currentSmoker      0
# cigsPerDay         0
# BPMeds             0
# prevalentStroke    0
# prevalentHyp       0
# diabetes           0
# totChol            0
# sysBP              0
# diaBP              0
# BMI                0
# heartRate          0
# glucose            0
# TenYearCHD         0
# dtype: int64

# %%
data.isnull().sum()
# Out:
# male                 0
# age                  0
# education          105
# currentSmoker        0
# cigsPerDay          29
# BPMeds              53
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol             50
# sysBP                0
# diaBP                0
# BMI                 19
# heartRate            1
# glucose            388
# TenYearCHD           0
# dtype: int64

# %%
data["education"].min()
# Out:
# 1.0

# %%
data.groupby("male").max()
# Out:
#       age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# male
# 0      70        4.0              1        50.0     1.0                1
# 1      69        4.0              1        70.0     1.0                1
#
#       prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  \
# male
# 0                1         1    600.0  295.0  142.5  56.80      143.0
# 1                1         1    696.0  235.0  136.0  40.38      125.0
#
#       glucose  TenYearCHD
# male
# 0       394.0           1
# 1       394.0           1

# %%
data.groupby("male").mean()
# Out:
#             age  education  currentSmoker  cigsPerDay    BPMeds  \
# male
# 0     49.795868   1.964105       0.408678    5.729730  0.037364
# 1     49.293407   2.000000       0.607692   13.368771  0.019391
#
#       prevalentStroke  prevalentHyp  diabetes     totChol       sysBP  \
# male
# 0            0.006198      0.308264  0.023554  239.441313  133.040083
# 1            0.005495      0.313736  0.028571  233.104799  131.443132
#
#           diaBP        BMI  heartRate   glucose  TenYearCHD
# male
# 0     82.296694  25.510723  77.097934  81.83605    0.124380
# 1     83.696978  26.185333  74.257284  82.12434    0.188462

# %%
x=data.groupby("education").mean()

# %%
type(x)
# Out:
# pandas.core.frame.DataFrame

# %%
x
# Out:
#                male        age  currentSmoker  cigsPerDay    BPMeds  \
# education
# 1.0        0.451744  51.941860       0.468023    8.683626  0.031324
# 2.0        0.390263  47.255387       0.541899    9.839228  0.030571
# 3.0        0.326560  48.727141       0.467344    8.111111  0.025000
# 4.0        0.583510  48.150106       0.507400    9.510638  0.027837
#
#            prevalentStroke  prevalentHyp  diabetes     totChol       sysBP  \
# education
# 1.0               0.008721      0.361047  0.034884  238.105418  135.849419
# 2.0               0.005587      0.286512  0.018356  235.389159  130.828013
# 3.0               0.004354      0.259797  0.020319  236.580645  129.403483
# 4.0               0.000000      0.270613  0.019027  234.702128  128.117336
#
#                diaBP        BMI  heartRate    glucose  TenYearCHD
# education
# 1.0        83.897384  26.567461  76.085515  83.080153    0.187791
# 2.0        82.325219  25.313732  76.718276  81.020390    0.117318
# ...

# %%
data["education"].count()
# Out:
# 4135

# %%
data["male"].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
data["education"].unique()
# Out:
# array([ 4.,  2.,  1.,  3., nan])

# %%
data["age"].unique()
# Out:
# array([39, 46, 48, 61, 43, 63, 45, 52, 50, 41, 38, 42, 44, 47, 60, 35, 36,
#        59, 54, 37, 56, 53, 49, 65, 51, 62, 40, 67, 57, 66, 64, 55, 58, 34,
#        68, 33, 70, 32, 69], dtype=int64)

# %%
data.nunique()
# Out:
# male                  2
# age                  39
# education             4
# currentSmoker         2
# cigsPerDay           33
# BPMeds                2
# prevalentStroke       2
# prevalentHyp          2
# diabetes              2
# totChol             248
# sysBP               234
# diaBP               146
# BMI                1364
# heartRate            73
# glucose             143
# TenYearCHD            2
# dtype: int64

# %%
data["male"].value_counts()
# Out:
# 0    2420
# 1    1820
# Name: male, dtype: int64

# %%
data["education"].value_counts()
# Out:
# 1.0    1720
# 2.0    1253
# 3.0     689
# 4.0     473
# Name: education, dtype: int64

# %%
data["age"].max()
# Out:
# 70

# %%
data.query("age>69")
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 1624     0   70        1.0              0         0.0     0.0
# 3137     0   70        2.0              0         0.0     1.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 1624                1             1         0    107.0  143.0   93.0    NaN
# 3137                0             1         0    231.0  136.0   84.0  31.78
#
#       heartRate  glucose  TenYearCHD
# 1624       68.0     62.0           1
# 3137       60.0     95.0           0

# %%
data.query("age>70")
# Out:
# Empty DataFrame
# Columns: [male, age, education, currentSmoker, cigsPerDay, BPMeds, prevalentStroke, prevalentHyp, diabetes, totChol, sysBP, diaBP, BMI, heartRate, glucose, TenYearCHD]
# Index: []

# %%
data.query("male==0")
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 1        0   46        2.0              0         0.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# 5        0   43        2.0              0         0.0     0.0
# 6        0   63        1.0              0         0.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4230     0   56        1.0              1         3.0     0.0
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
# 4239     0   39        3.0              1        30.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 1                   0             0         0    250.0  121.0   81.0  28.73
# ...

# %%
x=data.groupby("education").mean()

# %%
x
# Out:
#                male        age  currentSmoker  cigsPerDay    BPMeds  \
# education
# 1.0        0.451744  51.941860       0.468023    8.683626  0.031324
# 2.0        0.390263  47.255387       0.541899    9.839228  0.030571
# 3.0        0.326560  48.727141       0.467344    8.111111  0.025000
# 4.0        0.583510  48.150106       0.507400    9.510638  0.027837
#
#            prevalentStroke  prevalentHyp  diabetes     totChol       sysBP  \
# education
# 1.0               0.008721      0.361047  0.034884  238.105418  135.849419
# 2.0               0.005587      0.286512  0.018356  235.389159  130.828013
# 3.0               0.004354      0.259797  0.020319  236.580645  129.403483
# 4.0               0.000000      0.270613  0.019027  234.702128  128.117336
#
#                diaBP        BMI  heartRate    glucose  TenYearCHD
# education
# 1.0        83.897384  26.567461  76.085515  83.080153    0.187791
# 2.0        82.325219  25.313732  76.718276  81.020390    0.117318
# ...

# %%
x.to_csv("data1.csv")

# %%
data.query('diabetes==1')
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 37       1   52        1.0              0         0.0     0.0
# 44       0   53        3.0              0         0.0     1.0
# 56       0   54        1.0              1         9.0     0.0
# 66       0   62        1.0              0         0.0     0.0
# 96       0   63        4.0              1        20.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4096     0   56        1.0              0         0.0     0.0
# 4154     1   52        2.0              0         0.0     0.0
# 4203     1   63        1.0              1        10.0     0.0
# 4215     0   63        1.0              0         0.0     0.0
# 4228     0   50        1.0              0         0.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 37                  0             1         1    178.0  160.0   98.0  40.11
# ...

# %%
data[data["diabetes"]==1]
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 37       1   52        1.0              0         0.0     0.0
# 44       0   53        3.0              0         0.0     1.0
# 56       0   54        1.0              1         9.0     0.0
# 66       0   62        1.0              0         0.0     0.0
# 96       0   63        4.0              1        20.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4096     0   56        1.0              0         0.0     0.0
# 4154     1   52        2.0              0         0.0     0.0
# 4203     1   63        1.0              1        10.0     0.0
# 4215     0   63        1.0              0         0.0     0.0
# 4228     0   50        1.0              0         0.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 37                  0             1         1    178.0  160.0   98.0  40.11
# ...

# %%
pd.pivot_table(data1,values=["age","heartRate"],index=["male","currentSmoker"],aggfunc=[min,max])
# Out:
#                    min           max
#                    age heartRate age heartRate
# male currentSmoker
# 0    0              51      52.0  70     143.0
#      1              51      50.0  68     122.0
# 1    0              51      44.0  68     120.0
#      1              51      50.0  69     115.0

# %%
import pandas as pd
df=pd.DataFrame({'A': range(1,6),
                'B': range(10,0,-2),
                'C': range(10,5,-1)})

# %%
df
# Out:
#    A   B   C
# 0  1  10  10
# 1  2   8   9
# 2  3   6   8
# 3  4   4   7
# 4  5   2   6

# %%
df.query('B<C')
# Out:
#    A  B  C
# 1  2  8  9
# 2  3  6  8
# 3  4  4  7
# 4  5  2  6

# %%
df.query('A>B')
# Out:
#    A  B  C
# 4  5  2  6
