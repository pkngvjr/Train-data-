# %%
import matplotlib.pyplot as plt
import random
import numpy as np
import pandas as pd

# %%
df=pd.read_csv(r'C:\Users\RISHU YADAV\Downloads\covid_asia_weekly_trend.csv')

# %%
df
# Out:
#    Country/Other  Cases in the last 7 days  Cases in the preceding 7 days  \
# 0    Afghanistan                       288                            339
# 1        Armenia                      3640                           4965
# 2     Azerbaijan                     11615                          12763
# 3        Bahrain                       246                            182
# 4     Bangladesh                      1648                           1688
# 5         Bhutan                         7                              8
# 6         Brunei                       392                            410
# 7       Cambodia                       191                            307
# 8          China                       187                            187
# 9         Cyprus                      3445                           2604
# 10       Georgia                     26461                          28067
# 11     Hong Kong                        26                             22
# ...

# %%
age_of_students=np.random.randint(3,60, (20))
student_python=np.random.randint(3,60,(20))

# %%
age_of_students
# Out:
# array([43, 43, 58,  4,  7, 11, 22, 44, 38,  3, 52, 45, 26, 55, 11, 46, 16,
#        51, 38, 32])

# %%
student_python
# Out:
# array([18,  9, 11, 13, 35, 11, 21, 54, 16, 25, 29, 10,  3, 11, 58, 17, 52,
#        17, 46, 34])

# %%
plt.hist(student_python)
# Out:
# (array([1., 6., 4., 1., 2., 2., 0., 1., 1., 2.]),
#  array([ 3. ,  8.5, 14. , 19.5, 25. , 30.5, 36. , 41.5, 47. , 52.5, 58. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(age_of_students)
# Out:
# (array([3., 2., 1., 1., 1., 1., 2., 5., 2., 2.]),
#  array([ 3. ,  8.5, 14. , 19.5, 25. , 30.5, 36. , 41.5, 47. , 52.5, 58. ]),
#  <BarContainer object of 10 artists>)

# %%
df
# Out:
#    Country/Other  Cases in the last 7 days  Cases in the preceding 7 days  \
# 0    Afghanistan                       288                            339
# 1        Armenia                      3640                           4965
# 2     Azerbaijan                     11615                          12763
# 3        Bahrain                       246                            182
# 4     Bangladesh                      1648                           1688
# 5         Bhutan                         7                              8
# 6         Brunei                       392                            410
# 7       Cambodia                       191                            307
# 8          China                       187                            187
# 9         Cyprus                      3445                           2604
# 10       Georgia                     26461                          28067
# 11     Hong Kong                        26                             22
# ...

# %%
df.head()
# Out:
#   Country/Other  Cases in the last 7 days  Cases in the preceding 7 days  \
# 0   Afghanistan                       288                            339
# 1       Armenia                      3640                           4965
# 2    Azerbaijan                     11615                          12763
# 3       Bahrain                       246                            182
# 4    Bangladesh                      1648                           1688
#
#    Weekly Case % Change  Cases in the last 7 days/1M pop  \
# 0                   -15                                7
# 1                   -27                             1225
# 2                    -9                             1131
# 3                    35                              138
# 4                    -2                               10
#
#    Deaths in the last 7 days  Deaths in the preceding 7 days  \
# 0                          3                               8
# ...

# %%
df.isnull().sum()
# Out:
# Country/Other                       0
# Cases in the last 7 days            0
# Cases in the preceding 7 days       0
# Weekly Case % Change                0
# Cases in the last 7 days/1M pop     0
# Deaths in the last 7 days           0
# Deaths in the preceding 7 days      0
# Weekly Death % Change               0
# Deaths in the last 7 days/1M pop    0
# Population                          0
# dtype: int64

# %%
df.sample()
# Out:
#    Country/Other  Cases in the last 7 days  Cases in the preceding 7 days  \
# 40    Tajikistan                         0                              4
#
#     Weekly Case % Change  Cases in the last 7 days/1M pop  \
# 40                  -100                                0
#
#     Deaths in the last 7 days  Deaths in the preceding 7 days  \
# 40                          0                               0
#
#     Weekly Death % Change  Deaths in the last 7 days/1M pop  Population
# 40                      0                                 0     9839683

# %%
df.describe()
# Out:
#        Cases in the last 7 days  Cases in the preceding 7 days  \
# count                 48.000000                      48.000000
# mean               12680.687500                   12720.083333
# std                29438.043546                   28392.214578
# min                    0.000000                       4.000000
# 25%                  277.500000                     331.000000
# 50%                 2086.500000                    2222.500000
# 75%                 9265.500000                    8235.000000
# max               171008.000000                  167461.000000
#
#        Weekly Case % Change  Cases in the last 7 days/1M pop  \
# count             48.000000                        48.000000
# mean              -8.895833                       625.041667
# std               26.296379                      1146.419940
# min             -100.000000                         0.000000
# 25%              -18.250000                         9.750000
# ...

# %%
x=(df['Cases in the last 7 days'])

# %%
x
# Out:
# 0        288
# 1       3640
# 2      11615
# 3        246
# 4       1648
# 5          7
# 6        392
# 7        191
# 8        187
# 9       3445
# 10     26461
# 11        26
# 12     61013
# 13      2417
# 14     29436
# 15      5026
# 16      2355
# 17       710
# 18     30221
# 19      6023
# 20       185
# 21       398
# 22      9256
# 23     10214
# 24     35702
# 25       706
# 26      3329
# 27      3300
# 28      1667
# 29        45
# 30      2330
# 31      1843
# 32      4768
# 33      1072
# 34     26280
# 35       196
# 36      9294
# 37      5129
# 38       722
# 39        62
# 40         0
# 41     39737
# 42         2
# 43    171008
# 44       471
# 45      1458
# 46     94115
# 47        37
# Name: Cases in the last 7 days, dtype: int64

# %%
x=(df['Deaths in the last 7 days'])

# %%
x
# Out:
# 0        3
# 1      211
# 2      170
# 3        0
# 4       23
# 5        0
# 6        1
# 7       31
# 8        0
# 9        6
# 10     439
# 11       0
# 12    2663
# 13      77
# 14     645
# 15     108
# 16      19
# 17      10
# 18     205
# 19     119
# 20       0
# 21      17
# 22      33
# 23      59
# 24     315
# 25       2
# 26      45
# 27      63
# 28      17
# 29       0
# 30      60
# 31      20
# 32    1063
# 33       0
# 34     296
# 35       9
# 36      46
# 37     164
# 38      35
# 39       0
# 40       0
# 41     282
# 42       0
# 43    1399
# 44       3
# 45      20
# 46    1134
# 47       8
# Name: Deaths in the last 7 days, dtype: int64

# %%
y=(df[['Country/Other','Deaths in the last 7 days','Weekly Death % Change']])

# %%
y
# Out:
#    Country/Other  Deaths in the last 7 days  Weekly Death % Change
# 0    Afghanistan                          3                    -63
# 1        Armenia                        211                    -15
# 2     Azerbaijan                        170                     -8
# 3        Bahrain                          0                   -100
# 4     Bangladesh                         23                    -23
# 5         Bhutan                          0                      0
# 6         Brunei                          1                      1
# 7       Cambodia                         31                     -6
# 8          China                          0                      0
# 9         Cyprus                          6                      1
# 10       Georgia                        439                     -8
# 11     Hong Kong                          0                      0
# 12         India                       2663                      0
# ...

# %%
pop=(df[['Country/Other','Population']])

# %%
pop
# Out:
#    Country/Other  Population
# 0    Afghanistan    40164434
# 1        Armenia     2971068
# 2     Azerbaijan    10268225
# 3        Bahrain     1784842
# 4     Bangladesh   167006043
# 5         Bhutan      783603
# 6         Brunei      443394
# 7       Cambodia    17045531
# 8          China  1447175543
# 9         Cyprus     1219772
# 10       Georgia     3978346
# 11     Hong Kong     7582874
# 12         India  1399161383
# 13     Indonesia   277607186
# 14          Iran    85510446
# 15          Iraq    41495089
# 16        Israel     9326000
# 17         Japan   125929267
# 18        Jordan    10346151
# 19    Kazakhstan    19093759
# 20        Kuwait     4359700
# 21    Kyrgyzstan     6676068
# 22          Laos     7424555
# 23       Lebanon     6782245
# 24      Malaysia    32951341
# 25      Maldives      553975
# 26      Mongolia     3352781
# 27       Myanmar    54924965
# 28         Nepal    29876090
# 29          Oman     5289673
# 30      Pakistan   226941972
# ...

# %%
df.head()
# Out:
#   Country/Other  Cases in the last 7 days  Cases in the preceding 7 days  \
# 0   Afghanistan                       288                            339
# 1       Armenia                      3640                           4965
# 2    Azerbaijan                     11615                          12763
# 3       Bahrain                       246                            182
# 4    Bangladesh                      1648                           1688
#
#    Weekly Case % Change  Cases in the last 7 days/1M pop  \
# 0                   -15                                7
# 1                   -27                             1225
# 2                    -9                             1131
# 3                    35                              138
# 4                    -2                               10
#
#    Deaths in the last 7 days  Deaths in the preceding 7 days  \
# 0                          3                               8
# ...

# %%
maximum_case=(df[['Country/Other','Cases in the last 7 days']]).max()

# %%
maximum_case
# Out:
# Country/Other                Yemen
# Cases in the last 7 days    171008
# dtype: object

# %%
minimum_case=(df[['Country/Other','Cases in the last 7 days']]).min()

# %%
minimum_case
# Out:
# Country/Other               Afghanistan
# Cases in the last 7 days              0
# dtype: object

# %%
maximum_death=(df[['Country/Other','Deaths in the last 7 days']]).max()

# %%
maximum_death
# Out:
# Country/Other                Yemen
# Deaths in the last 7 days     2663
# dtype: object

# %%
minimum_death=(df[['Country/Other','Deaths in the last 7 days']]).min()

# %%
minimum_death
# Out:
# Country/Other                Afghanistan
# Deaths in the last 7 days              0
# dtype: object

# %%
x=(df['Country/Other'])

# %%
x
# Out:
# 0      Afghanistan
# 1          Armenia
# 2       Azerbaijan
# 3          Bahrain
# 4       Bangladesh
# 5           Bhutan
# 6           Brunei
# 7         Cambodia
# 8            China
# 9           Cyprus
# 10         Georgia
# 11       Hong Kong
# 12           India
# 13       Indonesia
# 14            Iran
# 15            Iraq
# 16          Israel
# 17           Japan
# 18          Jordan
# 19      Kazakhstan
# 20          Kuwait
# 21      Kyrgyzstan
# 22            Laos
# 23         Lebanon
# 24        Malaysia
# 25        Maldives
# 26        Mongolia
# 27         Myanmar
# 28           Nepal
# 29            Oman
# 30        Pakistan
# 31       Palestine
# 32     Philippines
# 33           Qatar
# 34        S. Korea
# 35    Saudi Arabia
# 36       Singapore
# 37       Sri Lanka
# 38           Syria
# 39          Taiwan
# 40      Tajikistan
# 41        Thailand
# 42     Timor-Leste
# 43          Turkey
# 44             UAE
# 45      Uzbekistan
# 46         Vietnam
# ...

# %%
y=(df['Cases in the last 7 days'])

# %%
y
# Out:
# 0        288
# 1       3640
# 2      11615
# 3        246
# 4       1648
# 5          7
# 6        392
# 7        191
# 8        187
# 9       3445
# 10     26461
# 11        26
# 12     61013
# 13      2417
# 14     29436
# 15      5026
# 16      2355
# 17       710
# 18     30221
# 19      6023
# 20       185
# 21       398
# 22      9256
# 23     10214
# 24     35702
# 25       706
# 26      3329
# 27      3300
# 28      1667
# 29        45
# 30      2330
# 31      1843
# 32      4768
# 33      1072
# 34     26280
# 35       196
# 36      9294
# 37      5129
# 38       722
# 39        62
# 40         0
# 41     39737
# 42         2
# 43    171008
# 44       471
# 45      1458
# 46     94115
# 47        37
# Name: Cases in the last 7 days, dtype: int64

# %%
plt.plot(x,y)

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 48 artists>

# %%
plt.pie(y,labels=x)
plt.show()

# %%
df["Cases in the last 7 days"].max()
# Out:
# 171008

# %%
df["Cases in the last 7 days"].min()
# Out:
# 0

# %%
df["Cases in the last 7 days"].mean()
# Out:
# 12680.6875

# %%
df[['Country/Other','Weekly Case % Change']].nlargest(5,['Weekly Case % Change'])
# Out:
#    Country/Other  Weekly Case % Change
# 39        Taiwan                    51
# 20        Kuwait                    46
# 3        Bahrain                    35
# 9         Cyprus                    32
# 31     Palestine                    25

# %%
max_cases_top_5_country = df[['Country/Other','Cases in the last 7 days']].nlargest(5,['Cases in the last 7 days'])
min_cases_top_5_country = df[['Country/Other','Cases in the last 7 days']].nsmallest(5,['Cases in the last 7 days'])

# %%
max_cases_top_5_country
# Out:
#    Country/Other  Cases in the last 7 days
# 43        Turkey                    171008
# 46       Vietnam                     94115
# 12         India                     61013
# 41      Thailand                     39737
# 24      Malaysia                     35702

# %%
min_cases_top_5_country
# Out:
#    Country/Other  Cases in the last 7 days
# 40    Tajikistan                         0
# 42   Timor-Leste                         2
# 5         Bhutan                         7
# 11     Hong Kong                        26
# 47         Yemen                        37

# %%
plt.plot(max_cases_top_5_country['Country/Other'],max_cases_top_5_country['Cases in the last 7 days'],color='r',marker='o')

# %%
y=(df['Cases in the last 7 days']).max()

# %%
y
# Out:
# 171008
