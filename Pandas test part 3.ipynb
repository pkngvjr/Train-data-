# %%
# Question (1):Go to framingum.csv and Take those People who are Male and  his education level is 3 and Heart Rate is grater than 65.
# Question (1):Repeat the Question 1 for Female
# Question (3) Write group by for making male as index and citrate per day in values for mean analysis
# Question (4) Repeat the Question 3 for Pivot
# Question (5) Create 2 csv file one contain only male and other contain only female 
# # Question (6) Create 2 csv file one contain only male and other contain only female with education level 3
# Question (7)Repeat Question 1 for Male
# Question(8) Create Pivot for Question 3

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r'C:\Users\RISHU YADAV\Downloads\framingham.csv')

# %%
df
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
# 4238     1   40        3.0              0         0.0     0.0
# 4239     0   39        3.0              1        30.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# ...

# %%
# Question (1):Go to framingum.csv and Take those People who are Male and  his education level is 3 and Heart Rate is grater than 65.

df.loc[(df['male']==1) & (df['education']==3)&(df['heartRate']>65),['male','education','heartRate']]
# Out:
#       male  education  heartRate
# 39       1        3.0       71.0
# 49       1        3.0       80.0
# 111      1        3.0       70.0
# 119      1        3.0       88.0
# 122      1        3.0       80.0
# ...    ...        ...        ...
# 4146     1        3.0       67.0
# 4178     1        3.0       68.0
# 4222     1        3.0       70.0
# 4231     1        3.0       80.0
# 4238     1        3.0       67.0
#
# [165 rows x 3 columns]

# %%
# Question (1):Repeat the Question 1 for Female

df.loc[(df['male']==0) & (df['education']==3)&(df['heartRate']>65),['male','education','heartRate']]
# Out:
#       male  education  heartRate
# 4        0        3.0       85.0
# 23       0        3.0       71.0
# 28       0        3.0       85.0
# 44       0        3.0       76.0
# 77       0        3.0       80.0
# ...    ...        ...        ...
# 4188     0        3.0       92.0
# 4214     0        3.0       76.0
# 4216     0        3.0       70.0
# 4229     0        3.0       75.0
# 4239     0        3.0       85.0
#
# [374 rows x 3 columns]

# %%
# Question (3) Write group by for making male as index and citrate per day in values for mean analysis

df.groupby(['male','cigsPerDay']).agg({'heartRate':['mean']})
# Out:
#                  heartRate
#                       mean
# male cigsPerDay
# 0    0.0         76.576520
#      1.0         77.372549
#      2.0         78.000000
#      3.0         74.197183
#      4.0         80.833333
#      5.0         76.880435
#      6.0         80.111111
#      7.0         72.571429
#      8.0         77.444444
#      9.0         77.170213
#      10.0        76.520408
#      11.0        68.666667
#      12.0        79.000000
#      14.0        76.500000
#      15.0        78.796460
#      16.0        78.000000
#      17.0        78.333333
#      18.0        76.750000
#      20.0        78.793333
#      23.0        85.000000
#      25.0        85.764706
#      30.0        75.420000
#      35.0        74.000000
#      40.0        83.727273
#      43.0        86.272727
#      50.0        90.000000
# 1    0.0         72.243697
#      1.0         71.750000
#      2.0         75.200000
#      3.0         71.793103
#      4.0         68.333333
# ...

# %%
# Question (4) Repeat the Question 3 for Pivot

table = pd.pivot_table(df, values='heartRate', index=['male','cigsPerDay'], aggfunc=np.mean)

# %%
table
# Out:
#                  heartRate
# male cigsPerDay
# 0    0.0         76.576520
#      1.0         77.372549
#      2.0         78.000000
#      3.0         74.197183
#      4.0         80.833333
#      5.0         76.880435
#      6.0         80.111111
#      7.0         72.571429
#      8.0         77.444444
#      9.0         77.170213
#      10.0        76.520408
#      11.0        68.666667
#      12.0        79.000000
#      14.0        76.500000
#      15.0        78.796460
#      16.0        78.000000
#      17.0        78.333333
#      18.0        76.750000
#      20.0        78.793333
#      23.0        85.000000
#      25.0        85.764706
#      30.0        75.420000
#      35.0        74.000000
#      40.0        83.727273
#      43.0        86.272727
#      50.0        90.000000
# 1    0.0         72.243697
#      1.0         71.750000
#      2.0         75.200000
#      3.0         71.793103
#      4.0         68.333333
#      5.0         71.034483
# ...

# %%
# Question (5) Create 2 csv file one contain only male and other contain only female

male=df.query('male==1')

# %%
male
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 8        1   52        1.0              0         0.0     0.0
# 9        1   43        1.0              1        30.0     0.0
# 12       1   46        1.0              1        15.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4231     1   58        3.0              0         0.0     0.0
# 4232     1   68        1.0              0         0.0     0.0
# 4233     1   50        1.0              1         1.0     0.0
# 4234     1   51        3.0              1        43.0     0.0
# 4238     1   40        3.0              0         0.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# ...

# %%
male.to_csv('male_data.csv')

# %%
female=df.query('male==0')

# %%
female
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 1        0   46        2.0              0         0.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# 5        0   43        2.0              0         0.0     0.0
# 6        0   63        1.0              0         0.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4230     0   56        1.0              1         3.0     0.0
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
# 4239     0   39        3.0              1        30.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 1                   0             0         0    250.0  121.0   81.0  28.73
# ...

# %%
female.to_csv('female_data.csv')

# %%
# Question (6) Create 2 csv file one contain only male and other contain only female with education level 3

male = df[(df.male==1) & (df.education==3)]

# %%
male
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 16       1   48        3.0              1        10.0     0.0
# 39       1   36        3.0              0         0.0     0.0
# 49       1   36        3.0              1        20.0     NaN
# 71       1   42        3.0              1        10.0     0.0
# 111      1   51        3.0              0         0.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4178     1   41        3.0              1        30.0     0.0
# 4222     1   53        3.0              0         0.0     0.0
# 4231     1   58        3.0              0         0.0     0.0
# 4234     1   51        3.0              1        43.0     0.0
# 4238     1   40        3.0              0         0.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 16                  0             1         0    232.0  138.0   90.0  22.37
# ...

# %%
male.to_csv('male_data.csv')

# %%
female = df[(df.male==0) & (df.education==3)]

# %%
female
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# 13       0   41        3.0              0         0.0     1.0
# 23       0   52        3.0              1        20.0     0.0
# 28       0   61        3.0              0         0.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4191     0   37        3.0              1        15.0     0.0
# 4214     0   56        3.0              1         5.0     0.0
# 4216     0   59        3.0              1        20.0     0.0
# 4229     0   51        3.0              1        20.0     0.0
# 4239     0   39        3.0              1        30.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 3                   0             1         0    225.0  150.0   95.0  28.58
# ...

# %%
female.to_csv('female_data.csv')

# %%
# Question (7)Repeat Question 1 for Male

df.loc[(df['male']==1) & (df['education']==3)&(df['heartRate']>65),['male','education','heartRate']]
# Out:
#       male  education  heartRate
# 39       1        3.0       71.0
# 49       1        3.0       80.0
# 111      1        3.0       70.0
# 119      1        3.0       88.0
# 122      1        3.0       80.0
# ...    ...        ...        ...
# 4146     1        3.0       67.0
# 4178     1        3.0       68.0
# 4222     1        3.0       70.0
# 4231     1        3.0       80.0
# 4238     1        3.0       67.0
#
# [165 rows x 3 columns]

# %%
# Question(8) Create Pivot for Question 3

table = pd.pivot_table(df, values='heartRate', index=['male','cigsPerDay'], aggfunc=np.mean)

# %%
table
# Out:
#                  heartRate
# male cigsPerDay
# 0    0.0         76.576520
#      1.0         77.372549
#      2.0         78.000000
#      3.0         74.197183
#      4.0         80.833333
#      5.0         76.880435
#      6.0         80.111111
#      7.0         72.571429
#      8.0         77.444444
#      9.0         77.170213
#      10.0        76.520408
#      11.0        68.666667
#      12.0        79.000000
#      14.0        76.500000
#      15.0        78.796460
#      16.0        78.000000
#      17.0        78.333333
#      18.0        76.750000
#      20.0        78.793333
#      23.0        85.000000
#      25.0        85.764706
#      30.0        75.420000
#      35.0        74.000000
#      40.0        83.727273
#      43.0        86.272727
#      50.0        90.000000
# 1    0.0         72.243697
#      1.0         71.750000
#      2.0         75.200000
#      3.0         71.793103
#      4.0         68.333333
#      5.0         71.034483
# ...
