# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_excel(r'C:\Users\RISHU YADAV\Downloads\superstore_Dataset.xlsx')

# %%
df
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 0       40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 1       26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# 2       25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18     First Class
# 3       13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30     First Class
# 4       47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06        Same Day
# ...       ...                       ...        ...        ...             ...
# 51285   29002   IN-2015-KE1642066-42174 2015-06-19 2015-06-19        Same Day
# 51286   34337  US-2014-ZD21925140-41765 2014-05-06 2014-05-10  Standard Class
# 51287   31315  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31    Second Class
# 51288    9596   MX-2013-RB1979518-41322 2013-02-17 2013-02-21  Standard Class
# 51289    6147   MX-2013-MC1810093-41416 2013-05-22 2013-05-26    Second Class
#
# ...

# %%
df.head()
# Out:
#    Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
# 3   13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
# 4   47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06      Same Day
#
#     Customer ID     Customer Name      Segment  Postal Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer      73120.0  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate          NaN     Wollongong
# 2     CR-127307      Craig Reiter     Consumer          NaN       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office          NaN         Berlin
# 4    RH-9495111       Rick Hansen     Consumer          NaN          Dakar
#
#    ...   Product ID    Category Sub-Category  \
# ...

# %%
df.tail()
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 51285   29002   IN-2015-KE1642066-42174 2015-06-19 2015-06-19        Same Day
# 51286   34337  US-2014-ZD21925140-41765 2014-05-06 2014-05-10  Standard Class
# 51287   31315  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31    Second Class
# 51288    9596   MX-2013-RB1979518-41322 2013-02-17 2013-02-21  Standard Class
# 51289    6147   MX-2013-MC1810093-41416 2013-05-22 2013-05-26    Second Class
#
#         Customer ID       Customer Name      Segment  Postal Code  \
# 51285    KE-1642066     Katrina Edelman    Corporate          NaN
# 51286  ZD-219251408  Zuschuss Donatelli     Consumer      37421.0
# 51287  ZD-219251404  Zuschuss Donatelli     Consumer      94109.0
# 51288    RB-1979518          Ross Baird  Home Office          NaN
# 51289    MC-1810093       Mick Crebagga     Consumer          NaN
#
#                 City  ...   Product ID         Category Sub-Category  \
# ...

# %%
df.isnull().sum()
# Out:
# Row ID                0
# Order ID              0
# Order Date            0
# Ship Date             0
# Ship Mode             0
# Customer ID           0
# Customer Name         0
# Segment               0
# Postal Code       41296
# City                  0
# State                 0
# Country               0
# Region                0
# Market                0
# Product ID            0
# Category              0
# Sub-Category          0
# Product Name          0
# Sales                 0
# Quantity              0
# Discount              0
# Profit                0
# Shipping Cost         0
# Order Priority        0
# dtype: int64

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales      Quantity      Discount  \
# count  51290.00000   9994.000000  51290.000000  51290.000000  51290.000000
# mean   25645.50000  55190.379428    246.490581      3.476545      0.142908
# std    14806.29199  32063.693350    487.565361      2.278766      0.212280
# min        1.00000   1040.000000      0.444000      1.000000      0.000000
# 25%    12823.25000  23223.000000     30.758625      2.000000      0.000000
# 50%    25645.50000  56430.500000     85.053000      3.000000      0.000000
# 75%    38467.75000  90008.000000    251.053200      5.000000      0.200000
# max    51290.00000  99301.000000  22638.480000     14.000000      0.850000
#
#              Profit  Shipping Cost
# count  51290.000000   51290.000000
# mean      28.610982      26.478567
# std      174.340972      57.251373
# min    -6599.978000       1.002000
# 25%        0.000000       2.610000
# 50%        9.240000       7.790000
# 75%       36.810000      24.450000
# ...

# %%
df[["Customer ID"]].value_counts()
# Out:
# Customer ID
# SV-203651406    26
# WB-218501404    24
# AP-109151404    23
# EM-1396082      21
# CS-121757       20
#                 ..
# NG-835595        1
# EJ-137201406     1
# EJ-1372039       1
# EJ-1372045       1
# DK-1309051       1
# Length: 17415, dtype: int64

# %%
df.groupby('Category').get_group('Technology')
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 0       40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 2       25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18     First Class
# 3       13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30     First Class
# 4       47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06        Same Day
# 5       22732    IN-2014-JM156557-41818 2014-06-28 2014-07-01    Second Class
# ...       ...                       ...        ...        ...             ...
# 51216   31885  US-2014-ZC21910140-41719 2014-03-21 2014-03-25  Standard Class
# 51227   32109  CA-2012-ZC21910140-41194 2012-10-12 2012-10-14     First Class
# 51261   35111  CA-2014-ZD21925140-41829 2014-07-09 2014-07-09        Same Day
# 51262   31316  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31    Second Class
# 51265   37195  CA-2014-ZD21925140-41733 2014-04-04 2014-04-10  Standard Class
#
# ...

# %%
df.groupby('Sub-Category').get_group('Phones')
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 0       40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 2       25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18     First Class
# 3       13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30     First Class
# 5       22732    IN-2014-JM156557-41818 2014-06-28 2014-07-01    Second Class
# 12      45794   SA-2012-MM7260110-41269 2012-12-26 2012-12-28    Second Class
# ...       ...                       ...        ...        ...             ...
# 51200   32343  CA-2014-ZC21910140-41707 2014-03-09 2014-03-14  Standard Class
# 51216   31885  US-2014-ZC21910140-41719 2014-03-21 2014-03-25  Standard Class
# 51261   35111  CA-2014-ZD21925140-41829 2014-07-09 2014-07-09        Same Day
# 51262   31316  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31    Second Class
# 51265   37195  CA-2014-ZD21925140-41733 2014-04-04 2014-04-10  Standard Class
#
# ...

# %%
df[["Customer Name","Customer ID"]].value_counts()
# Out:
# Customer Name     Customer ID
# Seth Vernon       SV-203651406    26
# William Brown     WB-218501404    24
# Arthur Prichep    AP-109151404    23
# Eric Murdock      EM-1396082      21
# Charles Sheldon   CS-121757       20
#                                   ..
# Erica Bern        EB-3975117       1
#                   EB-3975126       1
# Neil Französisch  NF-184751408     1
#                   NF-184751404     1
# Joseph Holt       JH-59853         1
# Length: 17415, dtype: int64

# %%
df.max()
# Out:
# Row ID                                         51290
# Order ID                    ZA-2015-TS11205146-42062
# Order Date                       2015-12-31 00:00:00
# Ship Date                        2016-01-07 00:00:00
# Ship Mode                             Standard Class
# Customer ID                               ZD-2192596
# Customer Name                     Zuschuss Donatelli
# Segment                                  Home Office
# Postal Code                                  99301.0
# City                           Águas Lindas de Goiás
# State                                         Žilina
# Country                                     Zimbabwe
# Region                                    Western US
# Market                                          USCA
# Product ID                               TEC-PH-6626
# Category                                  Technology
# Sub-Category                                  Tables
# Product Name      netTALK DUO VoIP Telephone Service
# ...

# %%
df.min()
# Out:
# Row ID                                                            1
# Order ID                                    AE-2012-PO8865138-41184
# Order Date                                      2012-01-01 00:00:00
# Ship Date                                       2012-01-03 00:00:00
# Ship Mode                                               First Class
# Customer ID                                             AA-10315102
# Customer Name                                         Aaron Bergman
# Segment                                                    Consumer
# Postal Code                                                  1040.0
# City                                                         Aachen
# State                                                        'Ajman
# Country                                                 Afghanistan
# Region                                                       Canada
# Market                                                       Africa
# ...

# %%
df["Sales"].max()
# Out:
# 22638.48

# %%
df.query("Sales>400")
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 1       26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# 2       25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18     First Class
# 3       13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30     First Class
# 4       47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06        Same Day
# 5       22732    IN-2014-JM156557-41818 2014-06-28 2014-07-01    Second Class
# ...       ...                       ...        ...        ...             ...
# 51193   36485  CA-2013-ZC21910140-41530 2013-09-13 2013-09-18  Standard Class
# 51195   33366  CA-2013-ZC21910140-41377 2013-04-13 2013-04-19  Standard Class
# 51200   32343  CA-2014-ZC21910140-41707 2014-03-09 2014-03-14  Standard Class
# 51204   32494  CA-2014-ZC21910140-41738 2014-04-09 2014-04-13  Standard Class
# 51261   35111  CA-2014-ZD21925140-41829 2014-07-09 2014-07-09        Same Day
#
# ...

# %%
df.query('Sales<400')
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 0       40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 8       40099  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 9       36258  CA-2012-AB10015140-40974 2012-03-06 2012-03-07     First Class
# 10      36259  CA-2012-AB10015140-40974 2012-03-06 2012-03-07     First Class
# 16      39519  CA-2012-AB10015140-40958 2012-02-19 2012-02-25  Standard Class
# ...       ...                       ...        ...        ...             ...
# 51285   29002   IN-2015-KE1642066-42174 2015-06-19 2015-06-19        Same Day
# 51286   34337  US-2014-ZD21925140-41765 2014-05-06 2014-05-10  Standard Class
# 51287   31315  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31    Second Class
# 51288    9596   MX-2013-RB1979518-41322 2013-02-17 2013-02-21  Standard Class
# 51289    6147   MX-2013-MC1810093-41416 2013-05-22 2013-05-26    Second Class
#
# ...

# %%
df["Customer Name"].count()
# Out:
# 51290

# %%
df.loc[0:51290,['Customer Name','Customer ID','City','Product Name']]
# Out:
#             Customer Name   Customer ID           City  \
# 0           Aaron Bergman  AB-100151402  Oklahoma City
# 1           Justin Ritter     JR-162107     Wollongong
# 2            Craig Reiter     CR-127307       Brisbane
# 3        Katherine Murray    KM-1637548         Berlin
# 4             Rick Hansen    RH-9495111          Dakar
# ...                   ...           ...            ...
# 51285     Katrina Edelman    KE-1642066           Kure
# 51286  Zuschuss Donatelli  ZD-219251408    Chattanooga
# 51287  Zuschuss Donatelli  ZD-219251404  San Francisco
# 51288          Ross Baird    RB-1979518       Valinhos
# 51289       Mick Crebagga    MC-1810093       Tipitapa
#
#                                         Product Name
# 0                                   Samsung Convoy 3
# 1          Novimex Executive Leather Armchair, Black
# 2                  Nokia Smart Phone, with Caller ID
# 3                     Motorola Smart Phone, Cordless
# ...

# %%
sns.barplot('Customer Name','Sales',data=df)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Customer Name', ylabel='Sales'>

# %%
sns.lineplot('Customer Name','Sales',data=df,hue='Segment')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Customer Name', ylabel='Sales'>

# %%
sns.lineplot('Customer Name','Sales',data=df)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Customer Name', ylabel='Sales'>

# %%
x=(df['Customer Name'])

# %%
x
# Out:
# 0             Aaron Bergman
# 1             Justin Ritter
# 2              Craig Reiter
# 3          Katherine Murray
# 4               Rick Hansen
#                 ...
# 51285       Katrina Edelman
# 51286    Zuschuss Donatelli
# 51287    Zuschuss Donatelli
# 51288            Ross Baird
# 51289         Mick Crebagga
# Name: Customer Name, Length: 51290, dtype: object

# %%
y=(df['Sales'])

# %%
y
# Out:
# 0         221.980
# 1        3709.395
# 2        5175.171
# 3        2892.510
# 4        2832.960
#            ...
# 51285      65.100
# 51286      16.720
# 51287       8.560
# 51288      13.440
# 51289      61.380
# Name: Sales, Length: 51290, dtype: float64

# %%
plt.plot(x,y)

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 51290 artists>
